# %% [markdown]
# <table style="text-align: center;">
#    <img src="tracking-basics.png"/>
# </tr>

# %% [markdown]
# <table style="text-align: center;">
#    <img src="autologging-intro.png"/>
# </tr>

# %%
import mlflow
import mlflow.sklearn
from sklearn.datasets import load_wine
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
mlflow.set_experiment("wine-simple")
mlflow.sklearn.autolog()
# Out:
# 2025/10/31 13:22:22 INFO mlflow.tracking.fluent: Experiment with name 'wine-simple' does not exist. Creating a new experiment.

# %%
wine = load_wine()
X_train, X_test, y_train, y_test = train_test_split(
    wine.data, wine.target, test_size=0.2, random_state=42
)

# %%
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
# Out:
# 2025/10/31 13:22:32 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '33318edd63454239bfd7b829b0d35bf1', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# RandomForestClassifier(random_state=42)

# %%
train_score = model.score(X_train, y_train)
test_score = model.score(X_test, y_test)

print(f"Train Accuracy: {train_score:.3f}")
print(f"Test Accuracy: {test_score:.3f}")
print("✓ Model automatically logged to MLflow!")
# Out:
# Train Accuracy: 1.000
# Test Accuracy: 1.000
# ✓ Model automatically logged to MLflow!

# %%
import subprocess
import time

ui_process = subprocess.Popen(["mlflow", "ui", "--port", "5001"])
time.sleep(2)
print("MLflow UI: http://127.0.0.1:5001")
# Out:
# MLflow UI: http://127.0.0.1:5001
# [MLflow] Security middleware enabled with default settings (localhost-only). To allow connections from other hosts, use --host 0.0.0.0 and configure --allowed-hosts and --cors-allowed-origins.
# INFO:     Uvicorn running on http://127.0.0.1:5001 (Press CTRL+C to quit)
# INFO:     Started parent process [37203]
# INFO:     Started server process [37205]
# INFO:     Waiting for application startup.
# INFO:     Started server process [37206]
# INFO:     Application startup complete.
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Started server process [37208]
# INFO:     Waiting for application startup.
# INFO:     Started server process [37207]
# INFO:     Application startup complete.
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     127.0.0.1:51659 - "GET / HTTP/1.1" 304 Not Modified
# ...

# %%
ui_process.terminate()
print("UI stopped")
# Out:
# UI stopped
# INFO:     127.0.0.1:52701 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52701 - "GET /static-files/static/js/main.4147aad8.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52702 - "GET /static-files/static/css/main.4d2fa021.css HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52701 - "GET /static-files/static/js/618.b02255b2.chunk.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52701 - "GET /static-files/static/js/225.98996b0b.chunk.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52702 - "GET /static-files/static/js/490.e46a7c21.chunk.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52708 - "GET /static-files/static/js/358.178855d8.chunk.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52709 - "GET /static-files/static/css/778.965d5efe.chunk.css HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52701 - "GET /static-files/static/js/863.5569b261.chunk.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:52701 - "GET /static-files/static/js/778.5a62a340.chunk.js HTTP/1.1" 200 OK
# ...
